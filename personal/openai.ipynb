# %%
from config import set_environment
from langchain_openai import OpenAI
open_ai_llm = OpenAI()
response = open_ai_llm.invoke("Tell me a joke about light bulbs!")
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 4
#       2 from langchain_openai import OpenAI
#       3 open_ai_llm = OpenAI()
# ----> 4 response = open_ai_llm.invoke("Tell me a joke about light bulbs!")
#       5 print(response)
#
# File /opt/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/langchain_core/language_models/llms.py:389, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     378 @override
#     379 def invoke(
#     380     self,
#    (...)
#     385     **kwargs: Any,
#     386 ) -> str:
#     387     config = ensure_config(config)
#     388     return (
# --> 389         self.generate_prompt(
#     390             [self._convert_input(input)],
#     391             stop=stop,
#     392             callbacks=config.get("callbacks"),
#     393             tags=config.get("tags"),
# ...
