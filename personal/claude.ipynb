# %%
from config import set_environment
from langchain_anthropic import ChatAnthropic
from langchain_core.messages import SystemMessage, HumanMessage
chat = ChatAnthropic(model="claude-3-opus-20240229")
messages = [
    SystemMessage(content="You're a helpful programming assistant"),
    HumanMessage(content="Write a Python function to calculate factorial")
]
response = chat.invoke(messages)
print(response)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[7], line 9
#       4 chat = ChatAnthropic(model="claude-3-opus-20240229")
#       5 messages = [
#       6     SystemMessage(content="You're a helpful programming assistant"),
#       7     HumanMessage(content="Write a Python function to calculate factorial")
#       8 ]
# ----> 9 response = chat.invoke(messages)
#      10 print(response)
#
# File /opt/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File /opt/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)
#     954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /opt/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File /opt/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File /opt/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/langchain_anthropic/chat_models.py:800, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#     798     return generate_from_stream(stream_iter)
#     799 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# --> 800 data = self._client.messages.create(**payload)
#     801 return self._format_output(data, **kwargs)
#
# File /opt/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/anthropic/resources/messages/messages.py:996, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     989 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#     990     warnings.warn(
#     991         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     992         UserWarning,
#     993         stacklevel=3,
#     994     )
# --> 996 return self._post(
#     997     "/v1/messages",
#     998     body=maybe_transform(
#     999         {
#    1000             "max_tokens": max_tokens,
#    1001             "messages": messages,
#    1002             "model": model,
#    1003             "cache_control": cache_control,
#    1004             "container": container,
#    1005             "inference_geo": inference_geo,
#    1006             "metadata": metadata,
#    1007             "output_config": output_config,
#    1008             "service_tier": service_tier,
#    1009             "stop_sequences": stop_sequences,
#    1010             "stream": stream,
#    1011             "system": system,
#    1012             "temperature": temperature,
#    1013             "thinking": thinking,
#    1014             "tool_choice": tool_choice,
#    1015             "tools": tools,
#    1016             "top_k": top_k,
#    1017             "top_p": top_p,
#    1018         },
#    1019         message_create_params.MessageCreateParamsStreaming
#    1020         if stream
#    1021         else message_create_params.MessageCreateParamsNonStreaming,
#    1022     ),
#    1023     options=make_request_options(
#    1024         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1025     ),
#    1026     cast_to=Message,
#    1027     stream=stream or False,
#    1028     stream_cls=Stream[RawMessageStreamEvent],
#    1029 )
#
# File /opt/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/anthropic/_base_client.py:1364, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1355     warnings.warn(
#    1356         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1357         "Please pass raw bytes via the `content` parameter instead.",
#    1358         DeprecationWarning,
#    1359         stacklevel=2,
#    1360     )
#    1361 opts = FinalRequestOptions.construct(
#    1362     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1363 )
# -> 1364 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/anthropic/_base_client.py:1137, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1134             err.response.read()
#    1136         log.debug("Re-raising status error")
# -> 1137         raise self._make_status_error_from_response(err.response) from None
#    1139     break
#    1141 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CZMxN8a2fv75khNapFCv7'}
